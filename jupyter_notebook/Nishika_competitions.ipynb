# %% [markdown]
# ## トレーニングデータセットの準備

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


#各トレーニングデータセットをインポート、結合
df1 = pd.read_csv('/train 2/01.csv')
df2 = pd.read_csv('/train 2/02.csv')
df3 = pd.read_csv('/train 2/03.csv')
df4 = pd.read_csv('/train 2/04.csv')
df5 = pd.read_csv('/train 2/05.csv')
df6 = pd.read_csv('/train 2/06.csv')
df7 = pd.read_csv('/train 2/07.csv')
df8 = pd.read_csv('/train 2/08.csv')
df9 = pd.read_csv('/train 2/09.csv')
df10 = pd.read_csv('/train 2/10.csv')
df11 = pd.read_csv('/train 2/11.csv')
df12 = pd.read_csv('/train 2/12.csv')
df13 = pd.read_csv('/train 2/13.csv')
df14 = pd.read_csv('/train 2/14.csv')
df15 = pd.read_csv('/train 2/15.csv')
df16 = pd.read_csv('/train 2/16.csv')
df17 = pd.read_csv('/train 2/17.csv')
df18 = pd.read_csv('/train 2/18.csv')
df19 = pd.read_csv('/train 2/19.csv')
df20 = pd.read_csv('/train 2/20.csv')
df21 = pd.read_csv('/train 2/21.csv')
df22 = pd.read_csv('/train 2/22.csv')
df23 = pd.read_csv('/train 2/23.csv')
df24 = pd.read_csv('/train 2/24.csv')
df25 = pd.read_csv('/train 2/25.csv')
df26 = pd.read_csv('/train 2/26.csv')
df27 = pd.read_csv('/train 2/27.csv')
df28 = pd.read_csv('/train 2/28.csv')
df29 = pd.read_csv('/train 2/29.csv')
df30 = pd.read_csv('/train 2/30.csv')
df31 = pd.read_csv('/train 2/31.csv')
df32 = pd.read_csv('/train 2/32.csv')
df33 = pd.read_csv('/train 2/33.csv')
df34 = pd.read_csv('/train 2/34.csv')
df35 = pd.read_csv('/train 2/35.csv')
df36 = pd.read_csv('/train 2/36.csv')
df37 = pd.read_csv('/train 2/37.csv')
df38 = pd.read_csv('/train 2/38.csv')
df39 = pd.read_csv('/train 2/39.csv')
df40 = pd.read_csv('/train 2/40.csv')
df41 = pd.read_csv('/train 2/41.csv')
df42 = pd.read_csv('/train 2/42.csv')
df43 = pd.read_csv('/train 2/43.csv')
df44 = pd.read_csv('/train 2/44.csv')
df45 = pd.read_csv('/train 2/45.csv')
df46 = pd.read_csv('/train 2/46.csv')
df47 = pd.read_csv('/train 2/47.csv')

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40, df41, df42, df43, df44, df45, df46, df47], axis=0, join='inner')

df = df.reset_index()
df.head()
# Out:
# /Users/katouwataru/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    index       ID        種類  地域  市区町村コード 都道府県名   市区町村名    地区名    最寄駅：名称  \
# 0      0  1055078  中古マンション等 NaN     1107   北海道   札幌市西区   発寒９条        発寒
# 1      1  1036058  中古マンション等 NaN     1104   北海道  札幌市白石区   菊水７条        菊水
# 2      2  1041911  中古マンション等 NaN     1105   北海道  札幌市豊平区   平岸１条  平岸(札幌市営)
# 3      3  1001976  中古マンション等 NaN     1101   北海道  札幌市中央区   北４条西     西１１丁目
# 4      4  1008213  中古マンション等 NaN     1101   北海道  札幌市中央区  南１６条西       幌平橋
#
#   最寄駅：距離（分）  ... 前面道路：方位 前面道路：種類  前面道路：幅員（ｍ）     都市計画  建ぺい率（％） 容積率（％）  \
# 0         6  ...     NaN     NaN         NaN  第１種住居地域     60.0  200.0
# 1         8  ...     NaN     NaN         NaN    準住居地域     60.0  300.0
# ...

# %%
#欠損値有無の確認
print(df.isnull().any())
# Out:
# index           False
# ID              False
# 種類              False
# 地域               True
# 市区町村コード         False
# 都道府県名           False
# 市区町村名           False
# 地区名              True
# 最寄駅：名称           True
# 最寄駅：距離（分）        True
# 間取り              True
# 面積（㎡）           False
# 土地の形状            True
# 間口               True
# 延床面積（㎡）          True
# 建築年              True
# 建物の構造            True
# 用途               True
# 今後の利用目的          True
# 前面道路：方位          True
# 前面道路：種類          True
# 前面道路：幅員（ｍ）       True
# 都市計画             True
# 建ぺい率（％）          True
# 容積率（％）           True
# 取引時点            False
# 改装               True
# 取引の事情等           True
# 取引価格（総額）_log    False
# dtype: bool

# %%
#各列の欠損値数の確認
df.isnull().sum()
# Out:
# index                0
# ID                   0
# 種類                   0
# 地域              662799
# 市区町村コード              0
# 都道府県名                0
# 市区町村名                0
# 地区名                658
# 最寄駅：名称            2650
# 最寄駅：距離（分）        23076
# 間取り              22954
# 面積（㎡）                0
# 土地の形状           662799
# 間口              662799
# 延床面積（㎡）         662799
# 建築年              19127
# 建物の構造            15595
# 用途               53943
# 今後の利用目的         363472
# 前面道路：方位         662799
# 前面道路：種類         662799
# 前面道路：幅員（ｍ）      662799
# 都市計画             18997
# 建ぺい率（％）          23050
# 容積率（％）           23050
# 取引時点                 0
# 改装               60076
# 取引の事情等          644339
# 取引価格（総額）_log         0
# dtype: int64

# %%
#各列のデータの種類数
print(df.nunique())
# Out:
# index           198606
# ID              662799
# 種類                   1
# 地域                   0
# 市区町村コード            618
# 都道府県名               47
# 市区町村名              618
# 地区名              12090
# 最寄駅：名称            3846
# 最寄駅：距離（分）           34
# 間取り                 63
# 面積（㎡）              196
# 土地の形状                0
# 間口                   0
# 延床面積（㎡）              0
# 建築年                 77
# 建物の構造               12
# 用途                  22
# 今後の利用目的              4
# 前面道路：方位              0
# 前面道路：種類              0
# 前面道路：幅員（ｍ）           0
# 都市計画                16
# 建ぺい率（％）              6
# 容積率（％）              17
# 取引時点                60
# 改装                   2
# 取引の事情等               9
# 取引価格（総額）_log       381
# dtype: int64

# %%
#分析に不要（IDや値の無い列）な列の削除
X_1 = df.drop(['index', 'ID', '種類', '地域', '土地の形状', '間口', '延床面積（㎡）', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）', '市区町村名'], axis=1)

# %%
#建築年列の年の文言を削除
X_1['建築年'] = X_1['建築年'].str.replace('年', '')

# %%
#元号列の追加
X_1['元号'] = ''
display(X_1)
# Out:
#         市区町村コード 都道府県名    地区名    最寄駅：名称 最寄駅：距離（分）   間取り 面積（㎡）   建築年 建物の構造   用途  \
# 0          1107   北海道   発寒９条        発寒         6  ３ＬＤＫ    75   平成9    ＲＣ   住宅
# 1          1104   北海道   菊水７条        菊水         8  ３ＬＤＫ    85  平成19    ＲＣ   住宅
# 2          1105   北海道   平岸１条  平岸(札幌市営)         3  ３ＬＤＫ    65  昭和49    ＲＣ   住宅
# 3          1101   北海道   北４条西     西１１丁目         9  ３ＬＤＫ    80  平成18    ＲＣ   住宅
# 4          1101   北海道  南１６条西       幌平橋         3    １Ｋ    25  昭和53    ＲＣ  NaN
# ...         ...   ...    ...       ...       ...   ...   ...   ...   ...  ...
# 662794    47201   沖縄県     安謝        古島   30分?60分    １Ｋ    30  平成18    ＲＣ   住宅
# 662795    47208   沖縄県     城間       NaN       NaN   ３ＤＫ    50   平成5    ＲＣ  NaN
# 662796    47201   沖縄県     安謝       NaN       NaN  ４ＬＤＫ    80  平成16    ＲＣ   住宅
# 662797    47201   沖縄県  おもろまち     おもろまち         6  ２ＬＤＫ    75  平成27    ＲＣ  NaN
# 662798    47201   沖縄県    字国場        安里   30分?60分  ３ＬＤＫ    60   平成6    ＲＣ   住宅
#
# ...

# %%
#建築年列の欠損値に「欠損補完」の文字列を挿入
X_1['建築年'].fillna('欠損補完', inplace=True)

# %%
#元号列に建築年列の元号の部分を複写
for i in range(len(X_1)):
    X_1['元号'][i] = X_1['建築年'][i][0:2]
    
display(X_1)
# Out:
# <ipython-input-11-5bf079e09c10>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_1['元号'][i] = X_1['建築年'][i][0:2]
#         市区町村コード 都道府県名    地区名    最寄駅：名称 最寄駅：距離（分）   間取り 面積（㎡）   建築年 建物の構造   用途  \
# 0          1107   北海道   発寒９条        発寒         6  ３ＬＤＫ    75   平成9    ＲＣ   住宅
# 1          1104   北海道   菊水７条        菊水         8  ３ＬＤＫ    85  平成19    ＲＣ   住宅
# 2          1105   北海道   平岸１条  平岸(札幌市営)         3  ３ＬＤＫ    65  昭和49    ＲＣ   住宅
# 3          1101   北海道   北４条西     西１１丁目         9  ３ＬＤＫ    80  平成18    ＲＣ   住宅
# 4          1101   北海道  南１６条西       幌平橋         3    １Ｋ    25  昭和53    ＲＣ  NaN
# ...         ...   ...    ...       ...       ...   ...   ...   ...   ...  ...
# 662794    47201   沖縄県     安謝        古島   30分?60分    １Ｋ    30  平成18    ＲＣ   住宅
# ...

# %% [markdown]
# ## テストデータセットの準備

# %%
#テストデータセットのインポート
df_test = pd.read_csv('test.csv')

display(df_test)
# Out:
#              ID        種類  地域  市区町村コード 都道府県名   市区町村名  地区名 最寄駅：名称 最寄駅：距離（分）  \
# 0       1000114  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         2
# 1       1000116  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         2
# 2       1000117  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         2
# 3       1000118  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         3
# 4       1000119  中古マンション等 NaN     1101   北海道  札幌市中央区  大通西  西１８丁目         3
# ...         ...       ...  ..      ...   ...     ...  ...    ...       ...
# 23199  47012519  中古マンション等 NaN    47208   沖縄県     浦添市   宮城    NaN       NaN
# 23200  47014760  中古マンション等 NaN    47211   沖縄県     沖縄市  安慶田    NaN       NaN
# 23201  47014956  中古マンション等 NaN    47211   沖縄県     沖縄市   大里    NaN       NaN
# 23202  47015505  中古マンション等 NaN    47211   沖縄県     沖縄市  比屋根    NaN       NaN
# 23203  47015950  中古マンション等 NaN    47211   沖縄県     沖縄市   与儀    NaN       NaN
#
#           間取り  ... 今後の利用目的  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）  \
# ...

# %%
#欠損値有無の確認
print(df_test.isnull().any())
# Out:
# ID            False
# 種類            False
# 地域             True
# 市区町村コード       False
# 都道府県名         False
# 市区町村名         False
# 地区名            True
# 最寄駅：名称         True
# 最寄駅：距離（分）      True
# 間取り            True
# 面積（㎡）         False
# 土地の形状          True
# 間口             True
# 延床面積（㎡）        True
# 建築年            True
# 建物の構造          True
# 用途             True
# 今後の利用目的        True
# 前面道路：方位        True
# 前面道路：種類        True
# 前面道路：幅員（ｍ）     True
# 都市計画           True
# 建ぺい率（％）        True
# 容積率（％）         True
# 取引時点          False
# 改装             True
# 取引の事情等         True
# dtype: bool

# %%
#各列のデータ種類数の確認
print(df_test.nunique())
# Out:
# ID            23204
# 種類                1
# 地域                0
# 市区町村コード         530
# 都道府県名            47
# 市区町村名           530
# 地区名            5987
# 最寄駅：名称         2631
# 最寄駅：距離（分）        34
# 間取り              29
# 面積（㎡）            55
# 土地の形状             0
# 間口                0
# 延床面積（㎡）           0
# 建築年              64
# 建物の構造             6
# 用途               11
# 今後の利用目的           4
# 前面道路：方位           0
# 前面道路：種類           0
# 前面道路：幅員（ｍ）        0
# 都市計画             15
# 建ぺい率（％）           6
# 容積率（％）           12
# 取引時点              2
# 改装                2
# 取引の事情等            4
# dtype: int64

# %%
X_test_1 = df_test.drop(['ID', '種類', '地域', '土地の形状', '間口', '延床面積（㎡）', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）', '市区町村名'], axis=1)

# %%
#テストデータにもトレーニングデータと同じ処理を行う
X_test_1['建築年'] = X_test_1['建築年'].str.replace('年', '')

X_test_1['元号'] = ''
display(X_test_1)
# Out:
#        市区町村コード 都道府県名  地区名 最寄駅：名称 最寄駅：距離（分）     間取り 面積（㎡）   建築年 建物の構造   用途  \
# 0         1101   北海道  大通西  西１８丁目         2    １ＬＤＫ    45   平成3   ＳＲＣ   住宅
# 1         1101   北海道  大通西  西１８丁目         2    １ＬＤＫ    45   平成3   ＳＲＣ   住宅
# 2         1101   北海道  大通西  西１８丁目         2    ２ＬＤＫ    50  昭和64   ＳＲＣ   住宅
# 3         1101   北海道  大通西  西１８丁目         3    ２ＬＤＫ    80   平成9    ＲＣ  NaN
# 4         1101   北海道  大通西  西１８丁目         3      １Ｋ    20  昭和56    ＲＣ  NaN
# ...        ...   ...  ...    ...       ...     ...   ...   ...   ...  ...
# 23199    47208   沖縄県   宮城    NaN       NaN    ３ＬＤＫ    90  平成21    ＲＣ  NaN
# 23200    47211   沖縄県  安慶田    NaN       NaN  ２ＬＤＫ＋Ｓ    65  昭和64    ＲＣ  NaN
# 23201    47211   沖縄県   大里    NaN       NaN    ２ＬＤＫ    35   平成3    ＲＣ  NaN
# 23202    47211   沖縄県  比屋根    NaN       NaN    ２ＬＤＫ    60  昭和59    ＲＣ  NaN
# 23203    47211   沖縄県   与儀    NaN       NaN    ２ＬＤＫ    55  平成26    ＲＣ   住宅
#
#       今後の利用目的                    都市計画  建ぺい率（％）  容積率（％）        取引時点   改装  \
# ...

# %%
X_test_1['建築年'].fillna('欠損補完', inplace=True)

for i in range(len(X_test_1)):
    X_test_1['元号'][i] = X_test_1['建築年'][i][0:2]
    
display(X_test_1)
# Out:
# <ipython-input-17-5bde9511cd55>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_1['元号'][i] = X_test_1['建築年'][i][0:2]
#        市区町村コード 都道府県名  地区名 最寄駅：名称 最寄駅：距離（分）     間取り 面積（㎡）   建築年 建物の構造   用途  \
# 0         1101   北海道  大通西  西１８丁目         2    １ＬＤＫ    45   平成3   ＳＲＣ   住宅
# 1         1101   北海道  大通西  西１８丁目         2    １ＬＤＫ    45   平成3   ＳＲＣ   住宅
# 2         1101   北海道  大通西  西１８丁目         2    ２ＬＤＫ    50  昭和64   ＳＲＣ   住宅
# 3         1101   北海道  大通西  西１８丁目         3    ２ＬＤＫ    80   平成9    ＲＣ  NaN
# 4         1101   北海道  大通西  西１８丁目         3      １Ｋ    20  昭和56    ＲＣ  NaN
# ...        ...   ...  ...    ...       ...     ...   ...   ...   ...  ...
# 23199    47208   沖縄県   宮城    NaN       NaN    ３ＬＤＫ    90  平成21    ＲＣ  NaN
# ...

# %% [markdown]
# ## 建築年列の整形

# %%
#X_test_1で作成したデータセットをX_testにコピー
X_test = X_test_1.copy()

# %%
print(X_test['元号'].unique())
# Out:
# ['平成' '昭和' '令和' '欠損' '戦前']

# %%
#建築年列の元号を消去
#欠損補完を-10に変換、戦前を10（昭和10年で統一）に変換
X_test['建築年'] = X_test['建築年'].str.replace('平成', '')
X_test['建築年'] = X_test['建築年'].str.replace('昭和', '')
X_test['建築年'] = X_test['建築年'].str.replace('令和', '')
X_test['建築年'] = X_test['建築年'].str.replace('欠損補完', '-10')
X_test['建築年'] = X_test['建築年'].str.replace('戦前', '10')
display(X_test)
#建築年のデータ種類を確認
print(X_test['建築年'].unique())
# Out:
#        市区町村コード 都道府県名  地区名 最寄駅：名称 最寄駅：距離（分）     間取り 面積（㎡） 建築年 建物の構造   用途  \
# 0         1101   北海道  大通西  西１８丁目         2    １ＬＤＫ    45   3   ＳＲＣ   住宅
# 1         1101   北海道  大通西  西１８丁目         2    １ＬＤＫ    45   3   ＳＲＣ   住宅
# 2         1101   北海道  大通西  西１８丁目         2    ２ＬＤＫ    50  64   ＳＲＣ   住宅
# 3         1101   北海道  大通西  西１８丁目         3    ２ＬＤＫ    80   9    ＲＣ  NaN
# 4         1101   北海道  大通西  西１８丁目         3      １Ｋ    20  56    ＲＣ  NaN
# ...        ...   ...  ...    ...       ...     ...   ...  ..   ...  ...
# 23199    47208   沖縄県   宮城    NaN       NaN    ３ＬＤＫ    90  21    ＲＣ  NaN
# 23200    47211   沖縄県  安慶田    NaN       NaN  ２ＬＤＫ＋Ｓ    65  64    ＲＣ  NaN
# 23201    47211   沖縄県   大里    NaN       NaN    ２ＬＤＫ    35   3    ＲＣ  NaN
# 23202    47211   沖縄県  比屋根    NaN       NaN    ２ＬＤＫ    60  59    ＲＣ  NaN
# 23203    47211   沖縄県   与儀    NaN       NaN    ２ＬＤＫ    55  26    ＲＣ   住宅
#
#       今後の利用目的                    都市計画  建ぺい率（％）  容積率（％）        取引時点   改装  \
# ...

# %%
#建築年列をint型へ変更
X_test['建築年'] = X_test['建築年'].astype(int)
print(X_test['建築年'].dtypes)
# Out:
# int64

# %%
#欠損値を元に戻す
X_test['建築年'] = X_test['建築年'].replace([-10], np.nan)

#欠損値に戻っているか確認
print(X_test['建築年'].unique())
print(X_test['建築年'].isnull().any())
# Out:
# [ 3. 64.  9. 56. 28. 61.  2. 60. 20. 19.  7. 10. 16. 59. 17. 58. 27. 18.
#  11. 13. 63. 29. 30. 25. 31. 49. 53. 54. 21. 52. 14.  8. 12. 51. 48.  6.
#  57. 46. 55. 44. 50. 62. 15. 23.  4. 39.  5. nan 24. 26. 45. 22. 47. 43.
#  41. 42. 34. 38. 36. 40.]
# True

# %%
#和暦を西暦に変換
for i in range(len(X_test)):
    if X_test['元号'][i] == '平成':
        X_test['建築年'][i] += 1988
    elif X_test['元号'][i] == '令和':
        X_test['建築年'][i] += 2018
    else:
        X_test['建築年'][i] += 1925

#元号列を削除
X_test = X_test.drop(['元号'], axis=1)
# Out:
# <ipython-input-24-a6ec90665e1e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['建築年'][i] += 1988
# <ipython-input-24-a6ec90665e1e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['建築年'][i] += 1925
# <ipython-input-24-a6ec90665e1e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['建築年'][i] += 2018

# %%
#トレーニングデータセットをXにコピー
X = X_1.copy()
display(X)
# Out:
#         市区町村コード 都道府県名    地区名    最寄駅：名称 最寄駅：距離（分）   間取り 面積（㎡）   建築年 建物の構造   用途  \
# 0          1107   北海道   発寒９条        発寒         6  ３ＬＤＫ    75   平成9    ＲＣ   住宅
# 1          1104   北海道   菊水７条        菊水         8  ３ＬＤＫ    85  平成19    ＲＣ   住宅
# 2          1105   北海道   平岸１条  平岸(札幌市営)         3  ３ＬＤＫ    65  昭和49    ＲＣ   住宅
# 3          1101   北海道   北４条西     西１１丁目         9  ３ＬＤＫ    80  平成18    ＲＣ   住宅
# 4          1101   北海道  南１６条西       幌平橋         3    １Ｋ    25  昭和53    ＲＣ  NaN
# ...         ...   ...    ...       ...       ...   ...   ...   ...   ...  ...
# 662794    47201   沖縄県     安謝        古島   30分?60分    １Ｋ    30  平成18    ＲＣ   住宅
# 662795    47208   沖縄県     城間       NaN       NaN   ３ＤＫ    50   平成5    ＲＣ  NaN
# 662796    47201   沖縄県     安謝       NaN       NaN  ４ＬＤＫ    80  平成16    ＲＣ   住宅
# 662797    47201   沖縄県  おもろまち     おもろまち         6  ２ＬＤＫ    75  平成27    ＲＣ  NaN
# 662798    47201   沖縄県    字国場        安里   30分?60分  ３ＬＤＫ    60   平成6    ＲＣ   住宅
#
# ...

# %%
#テストデータセットと同じ処理をトレーニングデータセットでも実行
X['建築年'] = X['建築年'].str.replace('平成', '')
X['建築年'] = X['建築年'].str.replace('昭和', '')
X['建築年'] = X['建築年'].str.replace('令和', '')
X['建築年'] = X['建築年'].str.replace('欠損補完', '-10')
X['建築年'] = X['建築年'].str.replace('戦前', '10')

X['建築年'] = X['建築年'].astype(int)
print(X['建築年'].dtypes)

X['建築年'] = X['建築年'].replace([-10], np.nan)

print(X['建築年'].unique())
print(X['建築年'].isnull().any())

for i in range(len(X)):
    if X['元号'][i] == '平成':
        X['建築年'][i] += 1988
    elif X['元号'][i] == '令和':
        X['建築年'][i] += 2018
    else:
        X['建築年'][i] += 1925

X = X.drop(['元号'], axis=1)
# Out:
# int64
# [ 9. 19. 49. 18. 53.  5. 24.  3. 11. 63. 59. 14.  7.  8.  4. 12. 17. 57.
#  21. 61. 58. 54.  2. 20. 52. 56.  6. 64. 16. 60. 15. 10. 28. 55. 62. 48.
#  29. 26. 51. 13. 25. nan 22. 23. 46. 50. 45. 27. 30. 31. 43. 44. 47. 39.
#  41. 42. 35. 40. 38. 37. 36. 34. 33. 32.]
# True
# <ipython-input-25-1d41d2d0c196>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['建築年'][i] += 1988
# <ipython-input-25-1d41d2d0c196>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['建築年'][i] += 1925
# <ipython-input-25-1d41d2d0c196>:20: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## カテゴリ変数の変換

# %%
#トレーニングデータセット、テストデータセット ともに各列の欠損値データを欠損補完の文字列で補完
X['間取り'].fillna('欠損補完', inplace=True)
X['用途'].fillna('住宅', inplace=True)
X['最寄駅：名称'].fillna('欠損補完', inplace=True)
X['今後の利用目的'].fillna('住宅', inplace=True)
X['都市計画'].fillna('欠損補完', inplace=True)
X['改装'].fillna('欠損補完', inplace=True)
X['取引の事情等'].fillna('欠損補完', inplace=True)
X['建物の構造'].fillna('欠損補完', inplace=True)
X['地区名'].fillna('欠損補完', inplace=True)

X_test['間取り'].fillna('欠損補完', inplace=True)
X_test['用途'].fillna('住宅', inplace=True)
X_test['最寄駅：名称'].fillna('欠損補完', inplace=True)
X_test['今後の利用目的'].fillna('住宅', inplace=True)
X_test['都市計画'].fillna('欠損補完', inplace=True)
X_test['改装'].fillna('欠損補完', inplace=True)
X_test['取引の事情等'].fillna('欠損補完', inplace=True)
X_test['建物の構造'].fillna('欠損補完', inplace=True)
X_test['地区名'].fillna('欠損補完', inplace=True)

# %%
#トレーニング、テストデータセットそれぞれの間取り列のデータをSeriesへ変換し、重複を削除（ラベルエンコード用の配列を作成）
seri1 = X['間取り']
seri2 = X_test['間取り']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoderオブジェクトを生成
encoder = LabelEncoder()

 # fit_transformメソッドで、間取りを整数値にエンコーディング
encoder.fit(seri)

#トレーニングデータセットの間取り列をラベルエンコード
classlabels_data = encoder.transform(X['間取り'])
X['間取り'] = classlabels_data

#テストデータセットの間取り列をラベルエンコード
classlabels_data = encoder.transform(X_test['間取り'])
X_test['間取り'] = classlabels_data

# %%
# 同じ手法で他のカテゴリデータ列もラベルエンコード
seri1 = X['用途']
seri2 = X_test['用途']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['用途'])
X['用途'] = classlabels_data

classlabels_data = encoder.transform(X_test['用途'])
X_test['用途'] = classlabels_data
    

seri1 = X['最寄駅：名称']
seri2 = X_test['最寄駅：名称']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['最寄駅：名称'])
X['最寄駅：名称'] = classlabels_data

classlabels_data = encoder.transform(X_test['最寄駅：名称'])
X_test['最寄駅：名称'] = classlabels_data


seri1 = X['今後の利用目的']
seri2 = X_test['今後の利用目的']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['今後の利用目的'])
X['今後の利用目的'] = classlabels_data
classlabels_data = encoder.transform(X_test['今後の利用目的'])
X_test['今後の利用目的'] = classlabels_data


seri1 = X['都市計画']
seri2 = X_test['都市計画']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['都市計画'])
X['都市計画'] = classlabels_data
classlabels_data = encoder.transform(X_test['都市計画'])
X_test['都市計画'] = classlabels_data


seri1 = X['改装']
seri2 = X_test['改装']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['改装'])
X['改装'] = classlabels_data
classlabels_data = encoder.transform(X_test['改装'])
X_test['改装'] = classlabels_data


seri1 = X['取引の事情等']
seri2 = X_test['取引の事情等']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['取引の事情等'])
X['取引の事情等'] = classlabels_data
classlabels_data = encoder.transform(X_test['取引の事情等'])
X_test['取引の事情等'] = classlabels_data


seri1 = X['建物の構造']
seri2 = X_test['建物の構造']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['建物の構造'])
X['建物の構造'] = classlabels_data
classlabels_data = encoder.transform(X_test['建物の構造'])
X_test['建物の構造'] = classlabels_data


seri1 = X['地区名']
seri2 = X_test['地区名']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['地区名'])
X['地区名'] = classlabels_data
classlabels_data = encoder.transform(X_test['地区名'])
X_test['地区名'] = classlabels_data

# %% [markdown]
# ## 取引時点列の整形

# %%
#取引時点列を西暦と四半期で分割
X_2 = X.iloc[:, 14].str.split('年', expand=True)
#西暦の部分を取引時点年列に転記
X['取引時点年'] = X_2[0]
#西暦の部分を取引時点四半期に転記
X['取引時点四半期'] = X_2[1]
#int型データに変換
X['取引時点四半期'] = X['取引時点四半期'].str.replace('第', '')
X['取引時点四半期'] = X['取引時点四半期'].str.replace('四半期', '')
X['取引時点四半期'] = X['取引時点四半期'].astype(int)
X['取引時点年'] = X['取引時点年'].astype(int)

#取引時点列を削除
X = X.drop(['取引時点'], axis=1)

# %%
#テストデータセットも同様に取引時点列を処理
X_test_2 = X_test.iloc[:, 14].str.split('年', expand=True)
X_test['取引時点年'] = X_test_2[0]
X_test['取引時点四半期'] = X_test_2[1]
X_test['取引時点四半期'] = X_test['取引時点四半期'].str.replace('第', '')
X_test['取引時点四半期'] = X_test['取引時点四半期'].str.replace('四半期', '')
X_test['取引時点四半期'] = X_test['取引時点四半期'].astype(int)
X_test['取引時点年'] = X_test['取引時点年'].astype(int)

X_test = X_test.drop(['取引時点'], axis=1)

# %% [markdown]
# ## 最寄駅：距離（分）列の整形

# %%
#最寄駅：距離（分）列のデータ内容を確認
print(X_test['最寄駅：距離（分）'].unique())
print(X_test['最寄駅：距離（分）'].dtypes)
# Out:
# ['2' '3' '1' '6' '4' '13' '8' '7' '5' '10' '9' '11' '15' '30分?60分' '16'
#  '14' '23' '24' '25' '26' '28' '0' '19' '18' '20' '17' '21' '12' '22'
#  '2H?' '1H?1H30' '29' '27' '1H30?2H' nan]
# object

# %%
#最寄駅：距離（分）列の全角文字などを処理
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('?', '')
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('分', '')
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('H', '500')

#曖昧な徒歩時間を固定数値に変換
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('3060', '45')
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('1500150030', '75')
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('2500', '130')
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('1500302500', '105')
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].str.replace('150030130', '105')

#トレーニングデータセットの最寄駅：距離（分）が欠損値の行を削除
X = X.dropna(subset=['最寄駅：距離（分）'])

#int型へ変換
X['最寄駅：距離（分）'] = X['最寄駅：距離（分）'].astype(int)
print(X['最寄駅：距離（分）'].dtypes)
# Out:
# int64

# %%
#テストデータセットも同様に処理
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('?', '')
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('分', '')
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('H', '500')

print(X_test['最寄駅：距離（分）'].unique())

X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('3060', '45')
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('1500150030', '75')
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('2500', '130')
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('1500302500', '105')
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].str.replace('150030130', '105')

print(X_test['最寄駅：距離（分）'].unique())

#テストデータ の欠損値は仮数値123で補完
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].fillna(123)

print(X_test['最寄駅：距離（分）'].unique())


#データ型変換後に仮数値123を元の欠損値に変換
X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].astype(int)

X_test['最寄駅：距離（分）'] = X_test['最寄駅：距離（分）'].replace([123], np.nan)

print(X_test['最寄駅：距離（分）'].unique())
# Out:
# ['2' '3' '1' '6' '4' '13' '8' '7' '5' '10' '9' '11' '15' '3060' '16' '14'
#  '23' '24' '25' '26' '28' '0' '19' '18' '20' '17' '21' '12' '22' '2500'
#  '1500150030' '29' '27' '1500302500' nan]
# ['2' '3' '1' '6' '4' '13' '8' '7' '5' '10' '9' '11' '15' '45' '16' '14'
#  '23' '24' '25' '26' '28' '0' '19' '18' '20' '17' '21' '12' '22' '130'
#  '75' '29' '27' '105' nan]
# ['2' '3' '1' '6' '4' '13' '8' '7' '5' '10' '9' '11' '15' '45' '16' '14'
#  '23' '24' '25' '26' '28' '0' '19' '18' '20' '17' '21' '12' '22' '130'
#  '75' '29' '27' '105' 123]
# [  2.   3.   1.   6.   4.  13.   8.   7.   5.  10.   9.  11.  15.  45.
#   16.  14.  23.  24.  25.  26.  28.   0.  19.  18.  20.  17.  21.  12.
#   22. 130.  75.  29.  27. 105.  nan]

# %%
#都道府県列もカテゴリ変数に変換
seri1 = X['都道府県名']
seri2 = X_test['都道府県名']
seri = pd.concat([seri1, seri2])
seri = seri.drop_duplicates()
encoder.fit(seri)
classlabels_data = encoder.transform(X['都道府県名'])
X['都道府県名'] = classlabels_data
classlabels_data = encoder.transform(X_test['都道府県名'])
X_test['都道府県名'] = classlabels_data

# %% [markdown]
# ## 築年数列の追加

# %%
#取引時点年と建築年の差分をとって取引時点の築年数を新しい説明変数として追加
X['取引時点築年'] = 0
X_test['取引時点築年'] = 0
X = X.reset_index()

for i in range(len(X)):
    X['取引時点築年'][i] = X['取引時点年'][i] - X['建築年'][i]
    
for i in range(len(X_test)):
    X_test['取引時点築年'][i] = X_test['取引時点年'][i] - X_test['建築年'][i]
# Out:
# <ipython-input-36-005322ccde34>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['取引時点築年'][i] = X['取引時点年'][i] - X['建築年'][i]
# /Users/katouwataru/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-36-005322ccde34>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
display(X)
display(X_test)
# Out:
#          index  市区町村コード  都道府県名    地区名  最寄駅：名称  最寄駅：距離（分）  間取り 面積（㎡）     建築年  \
# 0            0     1107      4   8720    2742          6   38    75  1997.0
# 1            1     1104      4  10002    3134          8   38    85  2007.0
# 2            2     1105      4   5451    1649          3   38    65  1974.0
# 3            3     1101      4   2364    3337          9   38    80  2006.0
# 4            4     1101      4   2812    1631          3    7    25  1978.0
# ...        ...      ...    ...    ...     ...        ...  ...   ...     ...
# 639718  662790    47201     28   7127    2791         11    3    55  1996.0
# 639719  662793    47201     28  11602    3673         14   48    85  1993.0
# 639720  662794    47201     28   4538     930         45    7    30  2006.0
# 639721  662797    47201     28     27      13          6   26    75  2015.0
# 639722  662798    47201     28   4433    1359         45   38    60  1994.0
#
# ...

# %%
#トレーニングデータセットのindex列を削除
X = X.drop(['index'], axis=1)

# %% [markdown]
# ## 面積（㎡）列の整形

# %%
#面積（㎡）列をstring型に変換
X['面積（㎡）'] = X['面積（㎡）'].astype(str)

#面積（㎡）列の内容を確認
print(X['面積（㎡）'].isnull().sum())
print(X_test['面積（㎡）'].isnull().sum())
print(X['面積（㎡）'].unique())
print(X_test['面積（㎡）'].unique())
# Out:
# 0
# 0
# ['75' '85' '65' '80' '25' '70' '90' '45' '55' '50' '60' '20' '40' '15'
#  '115' '100' '95' '30' '35' '110' '150' '105' '140' '120' '125' '145'
#  '165' '130' '10' '135' '190' '710' '200' '160' '185' '155' '250' '180'
#  '260' '360' '170' '220' '210' '2000㎡以上' '490' '450' '530' '470' '300'
#  '970' '600' '390' '440' '175' '740' '330' '230' '580' '1000' '290' '460'
#  '420' '270' '195' '860' '500' '310' '340' '370' '630' '280' '240' '430'
#  '680' '1500' '590' '1400' '380' '350' '820' '1200' '410' '320' '480'
#  '720' '560' '730' '870' '1300' '990' '520' '400' '770' '890' '690' '900'
#  '960' '660' '540' '1100' '780' '550' '940' '700' '670' '760' '650' '790'
#  '610' '510' '800' '830' '980' '570']
# ['45' '50' '80' '20' '70' '30' '65' '95' '15' '100' '85' '75' '60' '55'
#  '40' '105' '35' '90' '25' '130' '120' '115' '110' '150' '10' '140' '155'
#  '125' '145' '135' '180' '280' '185' '165' '210' '250' '350' '175' '450'
# ...

# %%
#面積（㎡）列の2000㎡以上を2000に変換
X['面積（㎡）'] = X['面積（㎡）'].str.replace('㎡以上', '')
X_test['面積（㎡）'] = X_test['面積（㎡）'].str.replace('㎡以上', '')

print(X['面積（㎡）'].isnull().sum())
print(X['面積（㎡）'].unique())
print(X_test['面積（㎡）'].unique())

#面積（㎡）列をint型に変換
X['面積（㎡）'] = X['面積（㎡）'].astype(int)
X_test['面積（㎡）'] = X_test['面積（㎡）'].astype(int)
# Out:
# 0
# ['75' '85' '65' '80' '25' '70' '90' '45' '55' '50' '60' '20' '40' '15'
#  '115' '100' '95' '30' '35' '110' '150' '105' '140' '120' '125' '145'
#  '165' '130' '10' '135' '190' '710' '200' '160' '185' '155' '250' '180'
#  '260' '360' '170' '220' '210' '2000' '490' '450' '530' '470' '300' '970'
#  '600' '390' '440' '175' '740' '330' '230' '580' '1000' '290' '460' '420'
#  '270' '195' '860' '500' '310' '340' '370' '630' '280' '240' '430' '680'
#  '1500' '590' '1400' '380' '350' '820' '1200' '410' '320' '480' '720'
#  '560' '730' '870' '1300' '990' '520' '400' '770' '890' '690' '900' '960'
#  '660' '540' '1100' '780' '550' '940' '700' '670' '760' '650' '790' '610'
#  '510' '800' '830' '980' '570']
# ['45' '50' '80' '20' '70' '30' '65' '95' '15' '100' '85' '75' '60' '55'
#  '40' '105' '35' '90' '25' '130' '120' '115' '110' '150' '10' '140' '155'
#  '125' '145' '135' '180' '280' '185' '165' '210' '250' '350' '175' '450'
# ...

# %% [markdown]
# ## 前処理後のデータセットの確認

# %%
#全ての列の整形が完了
display(X)
display(X_test)
# Out:
#         市区町村コード  都道府県名    地区名  最寄駅：名称  最寄駅：距離（分）  間取り  面積（㎡）     建築年  建物の構造  \
# 0          1107      4   8720    2742          6   38     75  1997.0      5
# 1          1104      4  10002    3134          8   38     85  2007.0      5
# 2          1105      4   5451    1649          3   38     65  1974.0      5
# 3          1101      4   2364    3337          9   38     80  2006.0      5
# 4          1101      4   2812    1631          3    7     25  1978.0      5
# ...         ...    ...    ...     ...        ...  ...    ...     ...    ...
# 639718    47201     28   7127    2791         11    3     55  1996.0      9
# 639719    47201     28  11602    3673         14   48     85  1993.0      5
# 639720    47201     28   4538     930         45    7     30  2006.0      5
# 639721    47201     28     27      13          6   26     75  2015.0      5
# 639722    47201     28   4433    1359         45   38     60  1994.0      5
#
# ...

# %% [markdown]
# XGboostを使って予測モデルを作成

# %% [markdown]
# ## 学習用データセットの作成

# %%
#トレーニングデータセットを説明変数と目的変数に分離
y = X['取引価格（総額）_log']
X = X.drop(['取引価格（総額）_log'], axis=1)

display(y)
# Out:
# 0         7.176091
# 1         7.361728
# 2         6.544068
# 3         7.518514
# 4         6.176091
#             ...
# 639718    7.176091
# 639719    7.041393
# 639720    6.903090
# 639721    7.778151
# 639722    7.255273
# Name: 取引価格（総額）_log, Length: 639723, dtype: float64

# %%
#トレーニングデータセットをtrainデータとvalデータに分割
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.3, random_state=123)

# %% [markdown]
# ##  XGBoostを使った予測モデル作成

# %%
#XGboostで予測モデル作成
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error

xgb_reg = xgb.XGBRegressor(max_depth=10, eta=0.1)

# %%
#trainデータによる学習
xgb_reg.fit(train_X, train_y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.1, gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.100000001, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#valデータを使って精度検証
oof_pred1 = xgb_reg.predict(val_X)

from sklearn.metrics import mean_absolute_error

print(30 * '=')
print(f'Mean Error: {mean_absolute_error(val_y, oof_pred1)}')
print(30 * '=')
# Out:
# ...
# Mean Error: 0.08811897012788149
# ...

# %% [markdown]
# ## 提出用ファイルの作成

# %%
#提出用フォーマットをインポート
submit1 = pd.read_csv('sample_submission.csv')

print(submit1)
# Out:
#              ID  取引価格（総額）_log
# 0       1000114             0
# 1       1000116             0
# 2       1000117             0
# 3       1000118             0
# 4       1000119             0
# ...         ...           ...
# 23199  47012519             0
# 23200  47014760             0
# 23201  47014956             0
# 23202  47015505             0
# 23203  47015950             0
#
# [23204 rows x 2 columns]

# %%
#テストデータセットを使った予測値を算出
oof_pred2 = xgb_reg.predict(X_test)

#提出用フォーマットに予測値を代入
submit1['取引価格（総額）_log'] = oof_pred2

#提出用ファイルの作成
submit1.to_csv('nishika_submission.csv', index=False)
